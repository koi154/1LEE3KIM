# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# local_people_2019 = pd.read_excel(
#     "./input/지역별 퇴사인력/지역별_퇴사인력__구인_및_채용인력_미충원인력_등__2019.xlsx")
# local_people_2019 = local_people_2019.iloc[3:, -6]
# local_people_2019
# new_2019 = []

# for i in range(len(local_people_2019)):
#     new_2019.append(local_people_2019.iloc[i])
# new_2019

# %%
# p = pd.read_excel("./input/연령별인구현황_2020.xlsx", skiprows=4)
# list = p.iloc[:, 3]
# data = []
# for i in range(len(p)):
#     num = list.iloc[i].replace(",", "")
#     data.append(int(num))
# data[5]+=data[7]
# del data[7]
# data
# Out:
# c:\Users\dawoo\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# [7231209,
#  2461682,
#  1751119,
#  2171715,
#  1033715,
#  1307986,
#  838950,
#  9782084,
#  1080135,
#  1132221,
#  1459144,
#  1224104,
#  1232578,
#  1827700,
#  2359396,
#  469839]

# %%
# local_people_2020 = pd.read_excel("./output/지역별_퇴사자3.xlsx")
# local_people_2020 = local_people_2020.iloc[:, [0, -9, -8, -7]]
# local_people_2020 = local_people_2020.rename(
#     columns={"2020.1": "경력", "2020.2": "입사경험", "2020.3": "신입"})
# local_people_2020 = local_people_2020.drop(index=0)
# list = local_people_2020.iloc[1:, 3]
# new_2020 = []
# for i in range(len(list)):
#     num_str = list.iloc[i].replace(",", "")
#     # print(num_str)
#     new_2020.append(int(num_str)/data[i]*100)
# new_2020
# Out:
# [0.10371709626979389,
#  0.07519249033790718,
#  0.09513916529944567,
#  0.1623141158024879,
#  0.0198313848594632,
#  0.15000160552177164,
#  0.22575838846176768,
#  0.12241767705122956,
#  0.046383091002513574,
#  0.2807755729667618,
#  0.23534346164600617,
#  0.08299948370399901,
#  0.05273499932661463,
#  0.03912020572303988,
#  0.35966832189255216,
#  0.015750076089894625]

# %%
local_people_2017 = pd.read_csv("./input/연령별퇴사/2017.csv")
local_people_2017
# Out:
#     성별(1)  연령별(1)   2017 2017.1 2017.2 2017.3 2017.4
# 0   성별(1)  연령별(1)     총계    진입자    유지자    이동자   미등록자
# 1      총계      총계  23379   3857  15648   3873   3404
# 2      총계  15-29세   3921   1372   1688    860    973
# 3      총계  30-39세   5085    630   3643    812    598
# 4      총계  40-49세   5854    640   4340    873    604
# 5      총계  50-59세   5220    617   3800    803    638
# 6      총계  60세 이상   3299    597   2177    526    592
# 7      남자      총계  13642   1908   9374   2359   1741
# 8      남자  15-29세   2005    738    830    437    508
# 9      남자  30-39세   3097    309   2250    537    288
# 10     남자  40-49세   3466    284   2646    536    289
# 11     남자  50-59세   3090    290   2294    506    323
# 12     남자  60세 이상   1984    287   1354    343    333
# 13     여자      총계   9737   1949   6273   1515   1663
# 14     여자  15-29세   1916    634    858    423    466
# 15     여자  30-39세   1988    321   1392    275    309
# 16     여자  40-49세   2387    356   1694    337    315
# ...

# %%
# work_time = pd.read_excel("./input/2020/실제_근무시간과_희망_근무시간_비교_2020.xlsx")
# total_people = work_time.iloc[10:27, 2]
# work_time_high = work_time.iloc[10:27, -2]
# work_time_low = work_time.iloc[10:27, 3]
# work_time_middle = work_time.iloc[10:27, 4]
# work_time
# total_people

# work_time_low_satisfied = []
# work_time_high_satisfied = []
# work_time_middle_satisfied = []
# for i in range(len(total_people)):
#     # print(total_people.iloc[i])
#     work_time_high_satisfied.append(
#         int(total_people.iloc[i]*work_time_high.iloc[i]/100+0.5))
#     work_time_low_satisfied.append(
#         int(total_people.iloc[i]*work_time_low.iloc[i]/100+0.5))
#     work_time_middle_satisfied.append(
#         int(total_people.iloc[i]*work_time_middle.iloc[i]/100+0.5))
# work_time_high_satisfied[5] += work_time_high_satisfied[7]
# work_time_low_satisfied[5] += work_time_low_satisfied[7]
# work_time_middle_satisfied[5] += work_time_middle_satisfied[7]
# del work_time_high_satisfied[7]
# del work_time_low_satisfied[7]
# del work_time_middle_satisfied[7]
# work_time_low_satisfied
# # work_time_high_satisfied
# # 적은 집단과 많은 집단을 두 개로 나눠서 데이터를 돌려보자
# Out:
# [1659,
#  379,
#  350,
#  306,
#  203,
#  292,
#  130,
#  2361,
#  214,
#  139,
#  286,
#  127,
#  289,
#  340,
#  368,
#  106]

# %%
work_time = pd.read_excel("./input/2020/실제_근무시간과_희망_근무시간_비교_2020.xlsx")
total_people = work_time.iloc[10:27, 2]
work_time_high = work_time.iloc[10:27, -2]
work_time_low = work_time.iloc[10:27, 3]


work_time_not_satisfied = []

for i in range(len(total_people)):
    # print(total_people.iloc[i])
    work_time_not_satisfied.append(work_time_high.iloc[i]+work_time_low.iloc[i])
   

work_time_not_satisfied[5] += work_time_not_satisfied[7]
del work_time_not_satisfied[7]

work_time_not_satisfied
# work_time_high_satisfied
# 적은 집단과 많은 집단을 두 개로 나눠서 데이터를 돌려보자
# Out:
# [25.9,
#  25.2,
#  26.1,
#  22.1,
#  29.5,
#  56.5,
#  20.9,
#  26.8,
#  24.5,
#  15.7,
#  24.6,
#  22.7,
#  30.1,
#  26.6,
#  23.700000000000003,
#  24.6]

# %%
# mean = int(pd.Series(new_2020).mean()+0.5)
# df_high = pd.DataFrame({"낮은_근무시간": work_time_low_satisfied,
#                   "높은_근무시간": work_time_high_satisfied, "신입_퇴사자": new_2020})

# df_high["퇴사율"] = (df_high["신입_퇴사자"] > mean).astype(int)

# # correlation_low = df_high["낮은_근무시간"].corr(df_high["신입_퇴사자"])
# correlation_high = df_high["높은_근무시간"].corr(df_high["퇴사율"])
# # print(f"낮은 근무시간과 퇴사자 수의 상관관계 : {correlation_low}")
# print(f"높은 근무시간과 퇴사자 수의 상관관계 : {correlation_high}")
# df_high
# Out:
# 높은 근무시간과 퇴사자 수의 상관관계 : 0.48882453869913256
#     낮은_근무시간  높은_근무시간  신입_퇴사자  퇴사율
# 0      1659      811    7500    1
# 1       379      444    1851    0
# 2       350      302    1666    0
# 3       306      338    3525    1
# 4       203      207     205    0
# 5       292      224    1962    0
# 6       130      139    1894    0
# 7      2361     1154   11975    1
# 8       214      128     501    0
# 9       139      115    3179    1
# 10      286      220    3434    1
# 11      127      252    1016    0
# 12      289      192     650    0
# 13      340      316     715    0
# 14      368      371    8486    1
# 15      106       65      74    0

# %%
mean = int(pd.Series(new_2020).mean()+0.5)
df_not_satisfied = pd.DataFrame({"근무시간_불만족": work_time_not_satisfied, "신입_퇴사자": new_2020})

# correlation_low = df_high["낮은_근무시간"].corr(df_high["신입_퇴사자"])
correlation_not_satisfied = df_not_satisfied["근무시간_불만족"].corr(df_not_satisfied["신입_퇴사자"])
# print(f"낮은 근무시간과 퇴사자 수의 상관관계 : {correlation_low}")
print(f"근무시간 불만족과 퇴사자 수의 상관관계 : {correlation_not_satisfied}")
df_not_satisfied
# Out:
# 근무시간 불만족과 퇴사자 수의 상관관계 : -0.19233758903199363
#     근무시간_불만족    신입_퇴사자
# 0       25.9  0.103717
# 1       25.2  0.075192
# 2       26.1  0.095139
# 3       22.1  0.162314
# 4       29.5  0.019831
# 5       56.5  0.150002
# 6       20.9  0.225758
# 7       26.8  0.122418
# 8       24.5  0.046383
# 9       15.7  0.280776
# 10      24.6  0.235343
# 11      22.7  0.082999
# 12      30.1  0.052735
# 13      26.6  0.039120
# 14      23.7  0.359668
# 15      24.6  0.015750

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc("font", family=font_name)
sns.regplot(x=df_not_satisfied['근무시간_불만족'], y=df_not_satisfied['신입_퇴사자'])
# plt.scatter(x=df_not_satisfied["근무시간_불만족"],y=df_not_satisfied["신입_퇴사자"])
# Out:
# <Axes: xlabel='근무시간_불만족', ylabel='신입_퇴사자'>
# c:\Users\dawoo\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\dawoo\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


mean = int(pd.Series(new_2020).mean()+0.5)
df_low = pd.DataFrame({"낮은_근무시간": work_time_low_satisfied,
                  "높은_근무시간": work_time_not_satisfied, "신입_퇴사자": new_2020})

df_low["퇴사율"] = (df_low["신입_퇴사자"] < mean).astype(int)

correlation_low = df_low["낮은_근무시간"].corr(df_low["퇴사율"])
# correlation_high = df_high["높은_근무시간"].corr(df_high["퇴사율"])
print(f"낮은 근무시간과 퇴사자 수의 상관관계 : {correlation_low}")
# print(f"높은 근무시간과 퇴사자 수의 상관관계 : {correlation_high}")
df_low

font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc("font", family=font_name)
sns.regplot(x=df_low['낮은_근무시간'], y=df_low['퇴사율'])
# Out:
# 낮은 근무시간과 퇴사자 수의 상관관계 : -0.49160704663679466
# <Axes: xlabel='낮은_근무시간', ylabel='퇴사율'>
# c:\Users\dawoo\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\dawoo\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
