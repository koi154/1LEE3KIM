# %%
import pandas as pd

# %%
# data = pd.read_excel("./input/지역별_퇴사인력__구인_및_채용인력_미충원인력_등__2014_2022.xlsx")
data = pd.read_csv("./input/지역별_퇴사인력__구인_및_채용인력_미충원인력_등__2014_2022.csv",encoding="utf-8")
# data

# %%
# resignation = data[["2012.1","2012.2"]]
list = [data[["지역별(1)", "2014.1", "2014.2","2014.3"]]]
for i in range(2015, 2023):
    list.append(data[[f"{i}.1", f"{i}.2", f"{i}.3"]])
df_list = [pd.DataFrame(item) for item in list]

result_df = pd.concat(df_list, axis=1)
result_df = result_df.drop(0, axis=0)
result_df = result_df.rename(columns=lambda x: x.replace("지역별(1)", "지역"))
result_df.to_excel("./output/지역별_퇴사자3.xlsx", index=False)
# result_df.to_csv("./output/지역별_퇴사자2.cvs", index=False)

# %%
data1 = pd.read_csv("./output/지역별_퇴사자.csv", encoding="utf-8", index_col=1)
# data1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plt.figure(figsize=(25, 4))
data1 = data1.rename(columns=lambda x: x.replace(".", "_"))
print(data1.head())
# data1.set_index(data1["계"])

# data1
# sns.barplot(x=data1["계"], y=data1["계"].columns)
# Out:
#         지역  2012_2  2013_1  2013_2  2014_1  2014_2  2014_3  2015_1  2015_2  \
# 2012.1
# 경력자            신입자     경력자     신입자     경력자  입사 경력자     신입자     경력자  입사 경력자
# 68,220   계  58,588  78,325  54,697  86,795   6,198  52,405  97,586   9,707
# 18,102  서울   5,083  16,988   4,015  15,827     571   4,714  17,708     888
# 2,035   부산     946   4,686     493   3,612     529   1,167   3,123   1,206
# 2,805   대구   1,710   2,848   2,589   2,062      38   4,583   3,275     532
#
#         2015_3  ...  2019_3   2020_1  2020_2  2020_3   2021_1  2021_2  2021_3  \
# 2012.1          ...
# 경력자        신입자  ...     신입자      경력자  입사 경력자     신입자      경력자  입사 경력자     신입자
# 68,220  50,449  ...  48,048  110,037  12,489  48,634  110,506  12,608  49,044
# 18,102   8,140  ...   8,258   18,665   1,871   7,500   18,394   2,151   8,028
# 2,035      711  ...   1,805    2,887     160   1,851    2,888     381     916
# 2,805    3,067  ...     511    3,773     508   1,666    5,197     781   2,288
#
# ...

# %%
# data2 = pd.read_excel("./output/지역별_퇴사자1.xlsx")
# # data2=data2.rename(lambda x: x.replace("자",""))
# data_row = data2.iloc[1, 0:]
# plt.figure(figsize=(25, 20))
#
# plt.bar(, data_row.values)

# %%
data3 = pd.read_excel("./output/지역별_퇴사자2.xlsx", index_col=0)
data3
plt.figure(figsize=(25, 15))
sns.set(font="Malgun Gothic", rc={"axes.unicode_minus": False})
data_row = data3.iloc[1]
# data_row
colors = ["#B26600", "#4169E1", "#FFD700"]
x_labels = []
for i in range(2014, 2023):
    x_labels.append(f"{i}_경력")
    x_labels.append(f"입사경험")
    x_labels.append(f"신입")
sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
plt.xlabel("연도")
plt.ylabel("퇴사자 수")
plt.xticks(range(len(x_labels)), x_labels, rotation=0)
plt.title("연도별 퇴사자 수 (2014~2022)")
# Out:
# C:\Users\dawoo\AppData\Local\Temp\ipykernel_22520\2975851300.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
# C:\Users\dawoo\AppData\Local\Temp\ipykernel_22520\2975851300.py:13: UserWarning:
# The palette list has fewer values (3) than needed (27) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
# Text(0.5, 1.0, '연도별 퇴사자 수 (2014~2022)')

# %%
data3 = pd.read_excel("./output/지역별_퇴사자2.xlsx", index_col=0)
data3
plt.figure(figsize=(3, 5))
sns.set(font="Malgun Gothic", rc={"axes.unicode_minus": False})
data_row = data3.iloc[1,24:]
# data_row
colors = ["#B26600", "#4169E1", "#FFD700"]
x_labels = []

x_labels.append("경력")
x_labels.append("입사경험")
x_labels.append("신입")
sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
plt.xlabel("경력 구분")
plt.ylabel("퇴사자 수")
plt.xticks(range(len(x_labels)), x_labels, rotation=0)
plt.title("2022년 퇴사자 수")
# Out:
# C:\Users\dawoo\AppData\Local\Temp\ipykernel_22520\3718888752.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
# Text(0.5, 1.0, '2022년 퇴사자 수')

# %%
data_row
# Out:
# 2022.1    111046
# 2022.2     12800
# 2022.3     48878
# Name: 계, dtype: object
