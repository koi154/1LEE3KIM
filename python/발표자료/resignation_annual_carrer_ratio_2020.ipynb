# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data3 = pd.read_excel("./output/지역별_퇴사자2.xlsx", index_col=0)
data3
plt.figure(figsize=(25, 15))
sns.set(font="Malgun Gothic", rc={"axes.unicode_minus": False})
data_row = data3.iloc[1]
# data_row
colors = ["#B26600", "#4169E1", "#FFD700"]
x_labels = []
for i in range(2014, 2023):
    x_labels.append(f"{i}_경력")
    x_labels.append(f"입사경험")
    x_labels.append(f"신입")
sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
plt.xlabel("연도")
plt.ylabel("퇴사자 수")
plt.xticks(range(len(x_labels)), x_labels, rotation=0)
plt.title("연도별 퇴사자 수 (2014~2022)")
# Out:
# C:\Users\dawoo\AppData\Local\Temp\ipykernel_28396\2975851300.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
# C:\Users\dawoo\AppData\Local\Temp\ipykernel_28396\2975851300.py:13: UserWarning:
# The palette list has fewer values (3) than needed (27) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
# Text(0.5, 1.0, '연도별 퇴사자 수 (2014~2022)')

# %%
data3 = pd.read_excel("./output/지역별_퇴사자2.xlsx", index_col=0)
data3
plt.figure(figsize=(3, 5))
sns.set(font="Malgun Gothic", rc={"axes.unicode_minus": False})
data_row = data3.iloc[1,18:21]
# data_row
colors = ["#B26600", "#4169E1", "#FFD700"]
x_labels = []

x_labels.append("경력")
x_labels.append("입사경험")
x_labels.append("신입")
sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
plt.xlabel("경력 구분")
plt.ylabel("퇴사자 수")
plt.xticks(range(len(x_labels)), x_labels, rotation=0)
plt.title("2020년 퇴사자 수")
# Out:
# C:\Users\dawoo\AppData\Local\Temp\ipykernel_28396\1067375277.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_row.index, y=data_row.values, palette=colors)
# Text(0.5, 1.0, '2020년 퇴사자 수')

# %%
data3.iloc[1,18:21]
# Out:
# 2020.1    110037
# 2020.2     12489
# 2020.3     48634
# Name: 계, dtype: object
