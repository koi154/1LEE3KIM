# %%
# 데이터에 "600만 원 이상" 추가
categories = ["199만 원 이하", "200~299만 원", "300~399만 원", "400~599만 원", "600만 원 이상"]
negative_rates = [29, 21, 16, 13, 14]
neutral_rates = [34, 30, 29, 26, 29]
positive_rates = [37, 49, 55, 61, 54]

x = np.arange(len(categories))  # x축 위치
width = 0.25  # 막대 너비

plt.figure(figsize=(12, 6))

# 막대 그래프 생성
bars_neg = plt.bar(x - width, negative_rates, width, label='불만족 (1~3)', color=colors["불만족 (1~3)"], edgecolor="black")
bars_neu = plt.bar(x, neutral_rates, width, label='보통 (4)', color=colors["보통 (4)"], edgecolor="black")
bars_pos = plt.bar(x + width, positive_rates, width, label='만족 (5~7)', color=colors["만족 (5~7)"], edgecolor="black")

# 그래프 제목 및 레이블
plt.title("월평균 소득별 만족도 분포", fontsize=16, pad=20)
plt.xlabel("월평균 소득", fontsize=12)
plt.ylabel("비율 (%)", fontsize=12)
plt.xticks(x, categories, fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title="만족도 구분", fontsize=10, title_fontsize=12)

# 값 표시
add_labels(bars_neg, negative_rates)
add_labels(bars_neu, neutral_rates)
add_labels(bars_pos, positive_rates)

plt.tight_layout()
plt.show()
